# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# 1. 强制读取你当前文件夹下的 .env 密钥文件（这是在你的电脑上运行的必须步骤！）
load_dotenv(override=True)

# 2. 实例化大模型
model = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# 3. 设定系统消息（给 AI 赋予“物理老师”的人设）
sysmsg = "You are a Physics teacher"

# 4. 设定人类消息（你真正要问的问题）
humanmsg = "Explain the concept of Galaxy in simple terms."

# 5. 将消息打包成列表
messages = [SystemMessage(content=sysmsg), HumanMessage(content=humanmsg)]

# 6. 发送给大模型并打印回复
print("正在等待物理老师的解答...\n")
response = model.invoke(messages)
print(response.content)
# Out:
# 正在等待物理老师的解答...
#
# A galaxy is a huge collection of stars, gas, dust, and dark matter that are all held together by gravity. Think of it like a giant city in space, where each star is like a building. Galaxies can contain billions or even trillions of stars, along with planets, moons, and other celestial objects.
#
# There are different types of galaxies, such as spiral galaxies (like our Milky Way), which have a swirling shape, and elliptical galaxies, which are more rounded. Some galaxies are irregular in shape and don't fit neatly into these categories.
#
# In simple terms, a galaxy is a vast group of stars and other materials that make up a part of the universe, and there are billions of galaxies out there!
