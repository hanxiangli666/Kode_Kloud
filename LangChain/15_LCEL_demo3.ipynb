# %%
import os
from dotenv import load_dotenv, find_dotenv

# 1. 加载环境变量
# 使用 override=True 确保读取最新的 .env 配置
load_dotenv(find_dotenv(), override=True)

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 2. 定义链组件
prompt = ChatPromptTemplate.from_template("""
You are a helpful assistant.
Answer the following question: {question}
""")

# 初始化模型
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)

# 初始化解析器：将结果解析为纯字符串列表
output_parser = StrOutputParser()

# 3. 构建链 (LCEL)
chain = prompt | llm | output_parser

# 4. 准备批处理数据 (Demo3 的核心)
# 老师提到，批处理需要创建一个包含多个字典的列表
questions = [
    {"question": "Tell me about The Forrest Gump Movie"},
    {"question": "Tell me about Avatar Movie"}
]

print("--- 正在启动批处理 (并行执行) ---")

# 5. 调用 batch 方法
# 核心逻辑：LangChain 会自动并行处理列表中的每个 prompt，而不是顺序执行
responses = chain.batch(questions)

# 6. 处理输出结果
# response 现在是一个包含两个字符串的列表
for i, res in enumerate(responses):
    print(f"\n回答 {i+1}:")
    print(res)

print("\n--- 批处理任务结束 ---")
# Out:
# --- 正在启动批处理 (并行执行) ---
#
# 回答 1:
# "Forrest Gump" is a 1994 American film directed by Robert Zemeckis and based on the 1986 novel of the same name by Winston Groom. The film stars Tom Hanks as the titular character, Forrest Gump, a kind-hearted man with a low IQ who unintentionally influences several historical events in the 20th century while pursuing his childhood love, Jenny Curran, played by Robin Wright.
#
# The narrative is delivered through Forrest's unique perspective, as he recounts his life story to various strangers while sitting on a bench in a park. The film explores themes of destiny, love, and the impact of historical events on individual lives. Forrest experiences significant moments in American history, including the Vietnam War, the Civil Rights Movement, and the rise of technology, all while remaining blissfully unaware of their broader implications.
#
# The film features a notable supporting cast, including Gary Sinise as Lieutenant Dan Taylor, a soldier who becomes Forrest's close friend, and Sally Field as Forrest's mother. "Forrest Gump" is renowned for its innovative use of visual effects, which allowed Forrest to interact with historical figures like John F. Kennedy and Elvis Presley.
#
# The film was a commercial success and received critical acclaim, winning six Academy Awards, including Best Picture, Best Actor for Tom Hanks, and Best Director for Zemeckis. Its famous quotes, such as "Life is like a box of chocolates; you never know what you're gonna get," have become ingrained in popular culture.
#
# "Forrest Gump" continues to be celebrated for its heartwarming story, memorable characters, and exploration of the human experience, making it a beloved classic in cinema history.
#
# 回答 2:
# "Avatar" is a science fiction film directed by James Cameron, released in December 2009. It is set in the mid-22nd century on the lush, habitable moon of Pandora, which orbits a gas giant in the Alpha Centauri star system. The film explores themes of environmentalism, imperialism, and the conflict between technology and nature.
#
# The story follows Jake Sully, a paraplegic former Marine, who is selected to participate in the Avatar Program. This program allows him to control a genetically engineered hybrid body known as an "avatar," which resembles the indigenous Na'vi people of Pandora. As Jake navigates the Na'vi culture and learns about their deep connection to their environment, he finds himself torn between his loyalty to the human corporation seeking to exploit Pandora's resources and his growing bond with the Na'vi, particularly with a female Na'vi named Neytiri.
#
# "Avatar" was groundbreaking in its use of 3D technology and visual effects, setting new standards for filmmaking. It became a massive box office success, initially surpassing "Titanic" (also directed by Cameron) to become the highest-grossing film of all time, a title it held for several years. The film received critical acclaim for its visual effects, world-building, and themes, although some criticized its storyline for being derivative.
#
# The film's success led to the development of several sequels, with "Avatar: The Way of Water" released in December 2022, continuing the story of Jake and Neytiri as they face new challenges on Pandora. James Cameron has plans for additional sequels, expanding the universe established in the original film.
#
# --- 批处理任务结束 ---
