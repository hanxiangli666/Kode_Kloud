# %%
# ============================================================================
# [部分 1] 环境初始化与依赖导入 / Part 1: Environment Setup and Imports
# ============================================================================
import os
from dotenv import load_dotenv

# 强制加载 .env，确保可读取 OPENAI_API_KEY
# Force-load .env to ensure OPENAI_API_KEY is available
load_dotenv(override=True)

# ChatOpenAI：LangChain 的聊天模型适配器
# ChatOpenAI: LangChain adapter for chat models
from langchain_openai import ChatOpenAI

# ChatPromptTemplate：构建多角色消息模板
# MessagesPlaceholder：在模板中预留“历史消息插槽”
# ChatPromptTemplate: build multi-role message templates
# MessagesPlaceholder: reserve a slot for runtime chat history
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder


# ============================================================================
# [部分 2] 初始化模型 / Part 2: Initialize the Chat Model
# ============================================================================

# 指定模型版本有助于复现实验结果
# Specifying model version helps reproducibility
# temperature=0.0：减少随机性，便于稳定演示
# temperature=0.0: reduce randomness for stable demo behavior
model = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.0)


# ============================================================================
# [部分 3] 构建带“短期记忆插槽”的 Prompt / Part 3: Build Prompt with Short-term Memory Slot
# ============================================================================

# Prompt 结构说明：
# 1) system：设置能力角色与回答约束
# 2) history：运行时注入多轮历史消息
# 3) human：当前用户问题
#
# Prompt structure:
# 1) system: define role/ability + response constraints
# 2) history: inject prior conversation at runtime
# 3) human: current user question
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You're an assistant who's good at {ability}. Respond in 20 words or fewer.",
        ),
        MessagesPlaceholder(variable_name="history"),
        ("human", "{input}"),
    ]
)


# ============================================================================
# [部分 4] 组装基础链（LCEL）/ Part 4: Assemble Base Chain with LCEL
# ============================================================================

# LCEL 管道：Prompt -> Model
# LCEL pipeline: Prompt -> Model
base_chain = prompt | model


# ============================================================================
# [部分 5] 模拟短期记忆并执行调用 / Part 5: Simulate Short-term Memory and Invoke
# ============================================================================

if __name__ == "__main__":
    # 这里手动构造历史记录（教学演示版）
    # In production, you usually manage history automatically with
    # RunnableWithMessageHistory + Redis/SQLite/etc.
    # Here we keep manual history for educational clarity.
    chat_history = [
        ("human", "What's a right-angled triangle?"),
        (
            "ai",
            "A right-angled triangle has one angle of 90 degrees, with the other two angles summing to 90 degrees.",
        ),
    ]

    # 当前新问题依赖上文语境（other types 指代三角形类型）
    # New question depends on previous context
    new_question = "What are the other types?"

    print(f"Current question: {new_question}")
    print("Reasoning based on historical memory...\n")

    # 调用时传入三类变量：
    # - ability: system 角色参数
    # - input: 当前问题
    # - history: 历史消息（短期记忆）
    #
    # Pass three variable groups at invocation:
    # - ability: system-role variable
    # - input: current question
    # - history: prior messages (short-term memory)
    response = base_chain.invoke(
        {
            "ability": "math",
            "input": new_question,
            "history": chat_history,
        }
    )


    # ========================================================================
    # [部分 6] 输出最终结果 / Part 6: Print Final Response
    # ========================================================================

    print("=== AI Response ===")
    # ChatOpenAI 返回 AIMessage，对应文本在 .content
    # ChatOpenAI returns AIMessage; text is in .content
    print(response.content)
# Out:
# Current question: What are the other types?
# Reasoning based on historical memory...
#
# === AI Response ===
# Other types of triangles include equilateral (all sides equal), isosceles (two sides equal), and scalene (no sides equal).
